# %%
import pandas as pd

df = pd.read_csv("raw/SPX/2015/20150102_OData_SPX.csv")
display(df)
# Out:
#                             OptionKey Symbol ExpirationDate  AskPrice  \
# 0      SPX2015-01-17c100.002015-01-02    SPX     2015-01-17   1954.25
# 1      SPX2015-01-17p100.002015-01-02    SPX     2015-01-17      0.05
# 2      SPX2015-01-17c200.002015-01-02    SPX     2015-01-17   1854.20
# 3      SPX2015-01-17p200.002015-01-02    SPX     2015-01-17      0.05
# 4      SPX2015-01-17c250.002015-01-02    SPX     2015-01-17   1804.20
# ...                               ...    ...            ...       ...
# 6479  SPX2015-12-31p2500.002015-01-02    SPX     2015-12-31    477.50
# 6480  SPX2015-12-31c2600.002015-01-02    SPX     2015-12-31      1.90
# 6481  SPX2015-12-31p2600.002015-01-02    SPX     2015-12-31    574.50
# 6482  SPX2015-12-31c2700.002015-01-02    SPX     2015-12-31      0.90
# 6483  SPX2015-12-31p2700.002015-01-02    SPX     2015-12-31    672.50
#
#       AskSize  BidPrice  BidSize  LastPrice PutCall  StrikePrice  Volume  \
# ...

# %%
df2 = pd.read_csv('raw/SPX/2011/20110103_OData_SPX.csv')
display(df2)
# Out:
#                             OptionKey Symbol ExpirationDate  AskPrice  \
# 0      SPX2011-01-22c200.002011-01-03    SPX     2011-01-22   1071.40
# 1      SPX2011-01-22p200.002011-01-03    SPX     2011-01-22      0.05
# 2      SPX2011-01-22c300.002011-01-03    SPX     2011-01-22    971.40
# 3      SPX2011-01-22p300.002011-01-03    SPX     2011-01-22      0.05
# 4      SPX2011-01-22c350.002011-01-03    SPX     2011-01-22    921.40
# ...                               ...    ...            ...       ...
# 1933  SPX2011-12-30p1800.002011-01-03    SPX     2011-12-30    549.60
# 1934  SPX2011-12-30c1900.002011-01-03    SPX     2011-12-30      1.00
# 1935  SPX2011-12-30p1900.002011-01-03    SPX     2011-12-30    649.10
# 1936  SPX2011-12-30c2000.002011-01-03    SPX     2011-12-30      1.00
# 1937  SPX2011-12-30p2000.002011-01-03    SPX     2011-12-30    748.60
#
#       AskSize  BidPrice  BidSize  LastPrice PutCall  StrikePrice  Volume  \
# ...
